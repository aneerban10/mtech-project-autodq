# %%
import pandas as pd
from data_cleaner import preprocess_dataframe

df =pd.read_csv("data/kyc_data.csv")
df = preprocess_dataframe(df)
df.head()
# Out:
# C:\Users\aneer\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#   customer_id         kyc_type kyc_expiry     kyc_number   kyc_mode
# 0        C001           aadhar        NaT  XXXXXXXXX1234  biometric
# 1        C002         passport 2026-05-20       N1234567       vcip
# 2        C003         voter id        NaT       ID987654   physical
# 3        C004  driving license 2020-01-01     MH12DL1234  biometric
# 4        C005            adhar        NaT   XXXXXXXX12X4        app

# %%
from engine.executor_pandas import run_validation

results = run_validation("data/kyc_data.csv", "rules/kyc_rules.yaml")

for res in results:
    print(f"\nRule Failed: {res['rule']}")
    print(f"Number of violations: {res['failed_count']}")
    print(res['failed_rows'][['customer_id']])
# Out:
# C:\Users\aneer\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 1
#
# Rule Failed: Valid KYC Type
# Number of violations: 1
#   customer_id
# 7        C008
#
# Rule Failed: Expiry Required for DL/Passport
# Number of violations: 1
#   customer_id
# 8        C009
#
# Rule Failed: Expiry in Future
# Number of violations: 2
#   customer_id
# 3        C004
# 6        C007
#
# Rule Failed: KYC Number Present
# Number of violations: 1
#   customer_id
# 8        C009
#
# Rule Failed: Aadhar Number Masking Format
# Number of violations: 2
#   customer_id
# 0        C001
# 4        C005
#
# Rule Failed: Alphanumeric Passport/Voter
# Number of violations: 0
# Empty DataFrame
# Columns: [customer_id]
# Index: []
#
# Rule Failed: DL Length Check
# Number of violations: 1
#   customer_id
# 5        C006
#
# Rule Failed: Valid KYC Mode
# ...
